# %%
import numpy as np
import pandas as pd
import engine_GRASP as GRASP
from plotnine import *

# %%
grasp = GRASP.GRASP()

# %%
amp = GRASP.Instance("/home/adrian/UNIVERSIDAD/4to_Curso" +
    "/A.MIO/PROJECT/pythoncode/MDP_instances/Amparo.xlsx")

# %%
data = pd.DataFrame(np.array(grasp.perform_during(amp.matrix, 0.3, 4*60)).transpose(), columns=["Value", "Time"])
# Out:
# 0 at 0.049575090408325195 seconds with alpha  0.3
# 20463.0 at 0.10394835472106934 seconds with alpha  0.3
# 21252.0 at 1.0902941226959229 seconds with alpha  0.3
# 21259.0 at 7.9206297397613525 seconds with alpha  0.3
# 21330.0 at 65.96187496185303 seconds with alpha  0.3
# 21368.0 at 100.31424331665039 seconds with alpha  0.3
# 21438.0 at 177.3905110359192 seconds with alpha  0.3

# %%
plot = (

    ggplot(data, aes("Time", "Value")) + 
    
    geom_point() + 
    
    geom_line() + 
    
    scale_x_log10() + 
    
    theme_538() + 
    
    coord_cartesian(ylim=(20000,22000))
)

# %%
plot
# Out:
# /home/adrian/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
# <ggplot: (8753298539174)>
